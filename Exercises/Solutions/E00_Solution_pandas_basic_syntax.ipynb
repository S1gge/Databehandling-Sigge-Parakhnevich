# %%
import pandas as pd

# %%
# 1. Cities in Sweden. Create dataset.

cities_df = pd.DataFrame({'Kommun':['Malmö', 'Stockholm','Uppsala','Göteborg'],
    'Population':[347949, 975551, 233839,583056]})

cities_df
# Out:
#       Kommun  Population
# 0      Malmö      347949
# 1  Stockholm      975551
# 2    Uppsala      233839
# 3   Göteborg      583056

# %%
# 1a.

cities_df['Kommun']
# Out:
# 0        Malmö
# 1    Stockholm
# 2      Uppsala
# 3     Göteborg
# Name: Kommun, dtype: object

# %%
# 1b.

cities_df.loc[[3]]
# Out:
#      Kommun  Population
# 3  Göteborg      583056

# %%
# 1c.

sort_cities = cities_df.sort_values(by='Population', ascending = False).reset_index(drop=True)
sort_cities
# Out:
#       Kommun  Population
# 0  Stockholm      975551
# 1   Göteborg      583056
# 2      Malmö      347949
# 3    Uppsala      233839

# %%
# 1d.

sort_cities_3 =  sort_cities.iloc[:3].reset_index(drop=True)
sort_cities_3
# Out:
#       Kommun  Population
# 0  Stockholm      975551
# 1   Göteborg      583056
# 2      Malmö      347949

# %%
# 1e.

sort_cities['Population (%)'] = [1,2,3,4]
sort_cities
# Out:
#       Kommun  Population  Population (%)
# 0  Stockholm      975551               1
# 1   Göteborg      583056               2
# 2      Malmö      347949               3
# 3    Uppsala      233839               4

# %%
# 2. Cities in Sweden - real dataset.

df = pd.read_excel("komtopp50_2020.xlsx")
df = df.loc[3:]
df
# Out:
#    Unnamed: 0  Unnamed: 1    Unnamed: 2             Unnamed: 3  Unnamed: 4  \
# 3         NaN         NaN           NaN                    NaN         NaN
# 4        Rang         NaN        Kommun  Folkmängd 31 december         NaN
# 5        2020      2019.0           NaN                   2020      2019.0
# 6           1         1.0     Stockholm                 975551    974073.0
# 7           2         2.0      Göteborg                 583056    579281.0
# 8           3         3.0         Malmö                 347949    344166.0
# 9           4         4.0       Uppsala                 233839    230767.0
# 10          5         5.0     Linköping                 164616    163051.0
# 11          6         6.0        Örebro                 156381    155696.0
# 12          7         7.0      Västerås                 155551    154049.0
# 13          8         8.0   Helsingborg                 149280    147734.0
# ...

# %%
# 2a.1

df.head()
# Out:
#                                       Unnamed: 0  Unnamed: 1 Unnamed: 2  \
# 0                                            NaN         NaN        NaN
# 1  Sveriges 50 största kommuner efter folkmängd,         NaN        NaN
# 2  31 december 2020 jämfört med 31 december 2019         NaN        NaN
# 3                                            NaN         NaN        NaN
# 4                                           Rang         NaN     Kommun
#
#               Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0                    NaN         NaN         NaN
# 1                    NaN         NaN         NaN
# 2                    NaN         NaN         NaN
# 3                    NaN         NaN         NaN
# 4  Folkmängd 31 december         NaN  Förändring

# %%
# 2a.2

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  54 non-null     object
#  1   Unnamed: 1  51 non-null     float64
#  2   Unnamed: 2  51 non-null     object
#  3   Unnamed: 3  52 non-null     object
#  4   Unnamed: 4  51 non-null     float64
#  5   Unnamed: 5  51 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 2.8+ KB

# %%
# 2a.3

df.describe()
# Out:
#         Unnamed: 1     Unnamed: 4
# count    51.000000      51.000000
# mean     64.588235  121353.627451
# std     279.518599  149002.409627
# min       1.000000    2019.000000
# 25%      13.500000   61154.000000
# 50%      26.000000   84395.000000
# 75%      38.500000  113013.500000
# max    2019.000000  974073.000000

# %%
# 2b.
